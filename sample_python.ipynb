# %% [markdown]
# i. There are two list one is having multiple words and another is
# having Keywords Now we have to check Which keyword is present
# in first list and we can have regex as well

# %%
import keyword


def check_kword(lst):
    new_list = []
    k_list = keyword.kwlist
    for word in lst:
        if word in k_list:
            new_list.append(word)
    return new_list


def check_kword2(lst):
    k_list = keyword.kwlist
    return [x for x in lst if x in k_list]

def freq(keyword_list):
    dict1 = {}
    for i in keyword_list:
        dict1[i] = keyword_list.count(i)
    return dict1
    


if __name__ == '__main__':
    lst = ['mumbai', 'pune', 'nagpur', 'return', 'in', 'for', 'in']
    print(check_kword(lst))
#     print(check_kword2(lst))
    keyword_list = check_kword(lst)
    print(freq(keyword_list))
# Out:
# ['return', 'in', 'for', 'in']
# {'return': 1, 'in': 2, 'for': 1}

# %% [markdown]
# 20 Python - What is Multithreading and Multitasking in Python or any language?
#
# Multitasking-
# when the CPu is provided with multiple task is called as multitasking,
# CPU switch between different tasks so that each task can run properly
# Each task use separate memory and resources
# In multi tasking CPu switch between each task rapidly

# %% [markdown]
# 21.	 Python - Write a python program to print the number which is missing in a list ranging numbers 1 to 100.

# %%
def missing_list(lst):
    new_list = []
    for i in range(lst[0], lst[-1] + 1):
        if i not in lst:
            new_list.append(i)
    return new_list


def missing_list2(lst):
    list1 = [x for x in range(lst[0], lst[-1] + 1) if x not in lst]
    return list1


if __name__ == '__main__':
    lst = [1, 4, 5, 6, 7, 9]
    print(missing_list(lst))
    print(missing_list2(lst))

# %% [markdown]
# 22.	Python  - Check if reverse of a given string matches with given string in Python.

# %%
def palandrom(s):
    if s == s[::-1]:

        return "palandrom"
    else:

        return "not a palandrom"


if __name__ == '__main__':
    str1 = "Mumbai"
    str2 = "level"
    print(palandrom(str1))
    print(palandrom(str2))

# %% [markdown]
# 23.	Python - Given variable x='aaabbadcaa'
# Write code to get the result like – a3b2a1d1c1a2

# %%
from collections import OrderedDict


def count_of_char(input_str):
    dict = OrderedDict.fromkeys(input_str, 0)
    for ch in input_str:
        dict[ch] = dict[ch] + 1

    output = ''
    for key, value in dict.items():
        output = output + key + str(value)
    return output


if __name__ == '__main__':
    input_str = 'aaabbadcaa'

    print(count_of_char(input_str))

# %% [markdown]
# 25.	Python - Connecting to a SQL database and extract data in csv/json format

# %%
import mysql.connector as mysql
import pandas as pd

# creating the connections and cursor
conn = mysql.connect(host='localhost', database='retail', user='root', password='root')
    
cursor = conn.cursor()

# query to fetch the data
query = ("SELECT * FROM orders")

# execute the query
cursor.execute(query)

# The fetchall()  method fetches all rows of a query result set and returns a list of tuples

my_data = cursor.fetchall()

# type will be list
type(my_data)

# type will be tuple
type(my_data[0])


columns =["order_id",
         "order_date",
          "order_customer_id",
           "order_status"]

df = pd.DataFrame(my_data, columns =columns)

# file will be store in the location in csv format
df.to_csv(r'C:\Users\Kshitij kadu\Desktop\sample_data\kk\kk.csv')

# %% [markdown]
# 26.	Python - Take any sample data, create dataframes using pandas library, apply some transformations and store in SQL database

# %%
import pandas as pd

# reading the orders and order_items csv into pandas dataframe 

# schema for the csv


column = [
    "order_item_id",
    "order_item_order_id",
    "order_item_product_id",
    "order_item_quantity",
    "order_item_subtotal",
    "order_item_product_price"
]

# reading csv file 
order_items_data = pd.read_csv(r'C:\Users\Kshitij kadu\Desktop\sample_data\retail_csv\order_items\part-00000',
                           delimiter = ',',
                           names = column
                        )

# filter the dataframe
greater_subtotal = order_items_data[order_items_data['order_item_subtotal']>1000]
greater_subtotal


query = ("""INSERT INTO order_items
         (order_item_id, order_item_order_id, order_item_product_id,
         order_item_quantity, order_item_subtotal, order_item_product_price)
         VALUES
         (%s, %s, %s, %s, %s, %s)""")

def load_orders(connection, cursor, query, data):
    for rec in data:
        cursor.execute(query, rec)
    connection.commit()
    
load_orders(conn, cursor, query, greater_subtotal.values.tolist())
#  The df.values return values present
# in the dataframe.
# tolist() will convert those values into list.

# %% [markdown]
# 27.	Python - Create a class, objects, constructors, functions, and other oops
#      concepts (inheritance, polymorphism, encapsulation) in python

# %%
class Employee:
    
    # constructor in python
    def __init__(self, a, b, c):
        print(a+b+c)


    def get_emp(self):
        return "this is get_emp"


obj1 = Employee(1,3,5)
print(obj1.get_emp())

# %%
# Encap

class Employee:

    a = 10
    b = 20
    __c = 30
    # here the scope of the __c is limited to class only
    #
    print(__c)
    def emp_name(self, a):

        return a

obj = Employee()

print(obj.a)
print(obj.b)
print(obj.emp_name('ksk'))
# try to print c
# if we want to access the variable outsid of the class we need to use belo aproch
# _className__variableName
print(obj._Employee__c)

# %%
# encap 

class Car:
    var = 'kk'

    def __init__(self, speed, color):
        self.speed = speed
        self.color = color

    def set_var(self, value):
        self.var = value

    def get_var(self):
        return self.var

    def get_add(self, a, b):
        return a + b


def get_add(a, b):
    return a + b


print("add is", get_add(1, 3))
honda = Car(100, 'red')
print(honda.var)
print(honda.get_add(1, 5))
honda.set_var('xyz')
print(honda.get_var())
# print(honda.speed)
# print(honda.color)

# %%
# single inheritance
# https://www.youtube.com/watch?v=u9x475OGj_U
class Parent:
    # create a class
    def first(self):
        print('this is parent class')


#   SINGLE INHERITANCE

# create second class and mention parent class in that
class Child(Parent):

    def second(self):
        print("this is child class")


#         create the object of child
obj1 = Child()
obj1.first()
obj1.second()

# %%
# multiple
# https://www.youtube.com/watch?v=u9x475OGj_U

class Parent1:
    # create a class
    def first(self):
        print('this is parent1 class')


class Parent2:
    def first(self):
        print('this is parent2 class')

# if we have method with same name in both the class
# then the method from the parent will be called which is mention first in child class
# if we mention child class as -  class Child(Parent2, Parent1) then method from parent2 will be called
# if we mention class Child( Parent1, Parent2) then the method from parent 1 will be called
class Child(Parent2, Parent1):
    def second(self):
        print("this is child class")


obj1 = Child()
obj1.first()
obj1.second()
# obj1.third()

# %%
# multi level
# https://www.youtube.com/watch?v=u9x475OGj_U
class Parent1:
    # create a class
    def first(self):
        print('this is parent1 class')


class Parent2(Parent1):
    def first(self):
        print('this is parent2 class')


class Child(Parent2):
    def second(self):
        print("this is child class")


obj1 = Child()
obj1.first()
obj1.second()

# %%
# hybrid
# https://www.youtube.com/watch?v=u9x475OGj_U
# hybrid inheritance is the combination of two inheritance

class Parent1:
    # create a class
    def first(self):
        print('this is parent1 class')

# here we are using single inheritance
class Parent2(Parent1):
    def third(self):
        print('this is parent2 class')

# here we are using multiple inheritance
class Child(Parent2, Parent1):
    def second(self):
        print("this is child class")


obj1 = Child()
obj1.first()
obj1.second()
obj1.third()

# %%
# hirer
# https://www.youtube.com/watch?v=u9x475OGj_U
class Parent:
    # create a class
    def first(self):
        print('this is parent1 class')


class Child2(Parent):
    def first(self):
        print('this is Child2 class')


class Child1(Parent):
    def second(self):
        print("this is child1 class")


# object of child class
obj1 = Child1()
obj1.first()
obj1.second()

# object of Parent2 class
obj2 = Child2()
obj2.first()

# %%
# poly
class Employee:
    # when same function behave diff in diff condition depend on aurgement pass
    # this can be achive using method overloading and method overriding

    def emp_name(self, name=''):
        return 'emp class name is :' + name



obj = Employee()
# method overloading
# depend upon arg pass below function change the value
print(obj.emp_name())
print(obj.emp_name('abc'))

# %%
# poly
class Employee:
    # when same function behave diff in diff condition depend on aurgement pass
    # this can be achive using method overloading and method overriding

    def emp_name(self, name=''):
        return 'emp class name is :' + name


class Department(Employee):
    # because we have same method name with same argument in the  both classes
    # the object of Department is created so that method from Department will be called
    # method overriding
    def emp_name(self, name=''):
        return "dep. class" + name


obj = Department()
print(obj.emp_name())
print(obj.emp_name('abc'))

# %%
# super function
# https://www.youtube.com/watch?v=u9x475OGj_U
# super function is use to call the parent method directly into chile

class Parent:
    # create a class
    def first(self):
        print('this is parent class')


#   SINGLE INHERITANCE

# create second class and mention parent class in that
class Child(Parent):

    def second(self):
        super().first()
        print("this is child class")


#         create the object of child
obj1 = Child()
# obj1.first()
obj1.second()
